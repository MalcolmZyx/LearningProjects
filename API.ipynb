# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '5ce26cf5-4779-493d-8d1c-35a3302c17e0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# if this doesn't work (which was given by coinmarketcap.com) for pulling data, then put this in 
# Anaconda Prompt: "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# And if that also failed to work, use a local host url in Anaconda prompt
# Out:
# {'status': {'timestamp': '2025-01-12T02:25:35.127Z', 'error_code': 0, 'error_message': None, 'elapsed': 32, 'credit_count': 1, 'notice': None, 'total_count': 10591}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 11860, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'ftx-bankruptcy-estate', '2017-2018-alt-season'], 'max_supply': 21000000, 'circulating_supply': 19808871, 'total_supply': 19808871, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-01-12T02:24:00.000Z', 'quote': {'USD': {'price': 94457.01504135272, 'volume_24h': 18513254358.36298, 'volume_change_24h': -69.0373, 'percent_change_1h': 0.15133684, 'percent_change_24h': 0.22322446, 'percent_change_7d': -3.77783639, 'percent_change_30d': -5.05019347, 'percent_change_60d': 8.10131702, 'percent_change_90d': 50.95411692, 'market_cap': 1871086825999.2156, 'market_cap_dominance': 56.4584, 'fully_diluted_market_cap': 1983597315868.41, 'tvl': None, 'last_updated': '2025-01-12T02:24:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 9814, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'heco-ecosystem', 'binance-labs-portfolio', 'solana-ecosystem', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'tezos-ecosystem', 'near-protocol-ecosystem', 'velas-ecosystem', 'ethereum-pow-ecosystem', 'osmosis-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', 'zksync-era-ecosystem', 'viction-ecosystem', 'klaytn-ecosystem', 'sora-ecosystem', 'rsk-rbtc-ecosystem', 'starknet-ecosystem'], 'max_supply': None, 'circulating_supply': 120490689.42869566, 'total_supply': 120490689.42869566, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-01-12T02:25:00.000Z', 'quote': {'USD': {'price': 3279.39792655743, 'volume_24h': 11431491485.655554, 'volume_change_24h': -55.2971, 'percent_change_1h': 0.0653809, 'percent_change_24h': 1.17303612, 'percent_change_7d': -9.95229857, 'percent_change_30d': -15.81722178, 'percent_change_60d': 1.80135225, 'percent_change_90d': 33.92584606, 'market_cap': 395136917081.9398, 'market_cap_dominance': 11.9224, 'fully_diluted_market_cap': 395136917081.94, 'tvl': None, 'last_updated': '2025-01-12T02:25:00.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 1500, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': ['medium-of-exchange', 'enterprise-solutions', 'arring ...

# %%
import pandas as pd

pd.set_option('display.max_columns', None) # displays all columns
df = pd.json_normalize(data['data']) # puts dict into a table format
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name symbol       slug  num_market_pairs  \
# 0       1      Bitcoin    BTC    bitcoin             11860
# 1    1027     Ethereum    ETH   ethereum              9814
# 2      52          XRP    XRP        xrp              1500
# 3     825  Tether USDt   USDT     tether            112246
# 4    1839          BNB    BNB        bnb              2330
# 5    5426       Solana    SOL     solana               820
# 6      74     Dogecoin   DOGE   dogecoin              1143
# 7    3408         USDC   USDC   usd-coin             24647
# 8    2010      Cardano    ADA    cardano              1431
# 9    1958         TRON    TRX       tron              1102
# 10   5805    Avalanche   AVAX  avalanche               841
# 11  20947          Sui    SUI        sui               516
# 12  11419      Toncoin    TON    toncoin               647
# 13    512      Stellar    XLM    stellar               659
# 14   5994    Shiba Inu   SHIB  shiba-inu               925
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2013-08-04T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2013-12-15T00:00:00.000Z
# 7   2018-10-08T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2020-07-13T00:00:00.000Z
# 11  2022-07-12T08:03:11.000Z
# 12  2021-08-26T13:40:22.000Z
# 13  2014-08-05T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 3   [stablecoin, asset-backed-stablecoin, ethereum...           NaN
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 7   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 8   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 9   [media, payments, ethereum-ecosystem, tron-eco...           NaN
# 10  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 11  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 12  [pos, ethereum-ecosystem, layer-1, ftx-bankrup...           NaN
# 13  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 14  [memes, ethereum-ecosystem, doggone-doggerel, ...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.980887e+07  1.980887e+07            False       NaN         1
# 1         1.204907e+08  1.204907e+08             True       NaN         2
# 2         5.749312e+10  9.998667e+10            False       NaN         3
# 3         1.374514e+11  1.414371e+11             True       NaN         4
# 4         1.440062e+08  1.440062e+08            False       NaN         5
# 5         4.842121e+08  5.920022e+08             True       NaN         6
# 6         1.475866e+11  1.475866e+11             True       NaN         7
# 7         4.573443e+10  4.573443e+10            False       NaN         8
# 8         3.515821e+10  4.499512e+10            False       NaN         9
# 9         8.617527e+10  8.617525e+10             True       NaN        10
# 10        4.107793e+08  4.491156e+08            False       NaN        11
# 11        3.009569e+09  1.000000e+10            False       NaN        12
# 12        2.539973e+09  5.119662e+09             True       NaN        13
# 13        3.039840e+10  5.000179e+10            False       NaN        14
# 14        5.892553e+14  5.895084e+14            False       NaN        15
#
#    self_reported_circulating_supply self_reported_market_cap tvl_ratio  \
# 0                              None                     None      None
# 1                              None                     None      None
# 2                              None                     None      None
# 3                              None                     None      None
# 4                              None                     None      None
# 5                              None                     None      None
# 6                              None                     None      None
# 7                              None                     None      None
# 8                              None                     None      None
# 9                              None                     None      None
# 10                             None                     None      None
# 11                             None                     None      None
# 12                             None                     None      None
# 13                             None                     None      None
# 14                             None                     None      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2025-01-12T02:24:00.000Z     94457.015041          1.851325e+10
# 1   2025-01-12T02:25:00.000Z      3279.397927          1.143149e+10
# 2   2025-01-12T02:25:00.000Z         2.535086          8.517734e+09
# 3   2025-01-12T02:25:00.000Z         0.999576          5.697144e+10
# 4   2025-01-12T02:25:00.000Z       696.179877          1.292050e+09
# 5   2025-01-12T02:25:00.000Z       187.222135          2.091755e+09
# 6   2025-01-12T02:25:00.000Z         0.339246          1.495904e+09
# 7   2025-01-12T02:25:00.000Z         1.000046          3.727177e+09
# 8   2025-01-12T02:25:00.000Z         1.022616          1.177069e+09
# 9   2025-01-12T02:25:00.000Z         0.240587          4.374240e+08
# 10  2025-01-12T02:25:00.000Z        37.100013          2.614116e+08
# 11  2025-01-12T02:25:00.000Z         4.910933          9.370407e+08
# 12  2025-01-12T02:25:00.000Z         5.390247          1.446810e+08
# 13  2025-01-12T02:25:00.000Z         0.437758          7.697765e+08
# 14  2025-01-12T02:25:00.000Z         0.000022          4.087520e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -69.0373                     0.151337
# 1                      -55.2971                     0.065381
# 2                       61.9578                     0.938189
# 3                      -50.6764                    -0.007169
# 4                      -21.1115                    -0.006519
# 5                      -42.9444                     0.171274
# 6                      -51.9164                     0.402084
# 7                      -50.4731                     0.004200
# 8                       -3.7251                     0.709796
# 9                      -46.2618                    -0.048366
# 10                     -47.7340                     0.291581
# 11                     -64.4184                    -0.314776
# 12                     -27.3644                    -0.259391
# 13                      24.6129                     1.121447
# 14                     -12.3912                    -0.108055
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.223224                    -3.777836
# 1                       1.173036                    -9.952299
# 2                       8.257293                     5.894825
# 3                      -0.036164                    -0.027701
# 4                       0.804641                    -2.123581
# 5                       0.419798                   -13.334343
# 6                       1.820322                   -13.442331
# 7                       0.001273                     0.006673
# 8                      10.963844                    -3.712083
# 9                      -1.164077                    -9.791701
# 10                      2.260196                   -11.919098
# 11                     -3.193506                    -5.906422
# 12                      0.373940                    -5.437142
# 13                      7.307473                    -2.777229
# 14                      1.786391                    -9.253220
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -5.050193                      8.101317
# 1                     -15.817222                      1.801352
# 2                       8.393307                    269.496688
# 3                      -0.067539                     -0.145226
# 4                      -1.485822                     13.194153
# 5                     -17.457382                     -9.075737
# 6                     -16.244508                    -11.266998
# 7                       0.007443                      0.041641
# 8                      -7.776464                     85.506088
# 9                     -18.460460                     31.306988
# 10                    -29.231873                     12.273660
# 11                      4.821587                     63.231083
# 12                    -14.826833                     -0.590805
# 13                      3.716941                    235.786941
# 14                    -21.923184                    -13.257554
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      50.954117          1.871087e+12
# 1                      33.925846          3.951369e+11
# 2                     378.993879          1.457500e+11
# 3                      -0.002712          1.373930e+11
# 4                      21.893160          1.002542e+11
# 5                      26.129169          9.065522e+10
# 6                     208.972604          5.006821e+10
# 7                       0.012554          4.573655e+10
# 8                     197.221542          3.595333e+10
# 9                      48.178066          2.073262e+10
# 10                     27.608447          1.523992e+10
# 11                    119.954432          1.477979e+10
# 12                      4.239442          1.369108e+10
# 13                    386.304185          1.330714e+10
# 14                     25.304368          1.288876e+10
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          56.4584                        1.983597e+12
# 1                          11.9224                        3.951369e+11
# 2                           4.3979                        2.535086e+11
# 3                           4.1457                        1.413771e+11
# 4                           3.0251                        1.002542e+11
# 5                           2.7353                        1.108359e+11
# 6                           1.5108                        5.006821e+10
# 7                           1.3801                        4.573655e+10
# 8                           1.0849                        4.601770e+10
# 9                           0.6256                        2.073262e+10
# 10                          0.4598                        2.655429e+10
# 11                          0.4461                        4.910933e+10
# 12                          0.4132                        2.759625e+10
# 13                          0.4015                        2.188868e+10
# 14                          0.3889                        1.289430e+10
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-01-12T02:24:00.000Z          NaN           NaN
# 1           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 2           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 3           None  2025-01-12T02:25:00.000Z       1027.0      Ethereum
# 4           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 5           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 6           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 7           None  2025-01-12T02:25:00.000Z       1027.0      Ethereum
# 8           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 9           None  2025-01-12T02:25:00.000Z          NaN           NaN
# 10          None  2025-01-12T02:25:00.000Z          NaN           NaN
# 11          None  2025-01-12T02:25:00.000Z          NaN           NaN
# 12          None  2025-01-12T02:25:00.000Z          NaN           NaN
# 13          None  2025-01-12T02:25:00.000Z          NaN           NaN
# 14          None  2025-01-12T02:25:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              NaN           NaN                                         NaN
# 3              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                     timestamp
# 0  2025-01-11 18:25:36.978461
# 1  2025-01-11 18:25:36.978461
# 2  2025-01-11 18:25:36.978461
# 3  2025-01-11 18:25:36.978461
# 4  2025-01-11 18:25:36.978461
# 5  2025-01-11 18:25:36.978461
# 6  2025-01-11 18:25:36.978461
# 7  2025-01-11 18:25:36.978461
# 8  2025-01-11 18:25:36.978461
# 9  2025-01-11 18:25:36.978461
# 10 2025-01-11 18:25:36.978461
# 11 2025-01-11 18:25:36.978461
# 12 2025-01-11 18:25:36.978461
# 13 2025-01-11 18:25:36.978461
# 14 2025-01-11 18:25:36.978461

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '5ce26cf5-4779-493d-8d1c-35a3302c17e0',
    }
    
    session = Session()
    session.headers.update(headers)
    
    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # if this doesn't work (which was given by coinmarketcap.com) for pulling data, then put this in 
    # Anaconda Prompt: "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
    # And if that also failed to work, use a local host url in Anaconda prompt

    df2 = pd.json_normalize(data['data']) # puts dict into a table format
    df2['timestamp'] = pd.to_datetime('now')
    df = pd.concat([df, df2], ignore_index=True)

    # if not os.path.isfile(r'')
    #     df.to_csv(r'', header='column_names')
    # else:
    #     df.to_csv(r'',mode='a',header=False)

# %%
import os
from time import time
from time import sleep

for i in range(100): # max is 333 credits given by coinmarketcap.com
    api_runner()
    print('API Runner Completed')
    sleep(60) # sleep for 1 minute
exit()
# Out:
# API Runner Completed
# API Runner Completed
# API Runner Completed
# API Runner Completed
# API Runner Completed
# API Runner Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 8
#       6     api_runner()
#       7     print('API Runner Completed')
# ----> 8     sleep(60) # sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
#df43 = pd.read_csv(r'')
df
# Out:
#         id         name symbol       slug  num_market_pairs  \
# 0        1      Bitcoin    BTC    bitcoin             11860
# 1     1027     Ethereum    ETH   ethereum              9814
# 2       52          XRP    XRP        xrp              1500
# 3      825  Tether USDt   USDT     tether            112246
# 4     1839          BNB    BNB        bnb              2330
# ..     ...          ...    ...        ...               ...
# 100   5805    Avalanche   AVAX  avalanche               841
# 101  20947          Sui    SUI        sui               516
# 102  11419      Toncoin    TON    toncoin               647
# 103    512      Stellar    XLM    stellar               659
# 104   5994    Shiba Inu   SHIB  shiba-inu               925
#
#                    date_added  \
# 0    2010-07-13T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2013-08-04T00:00:00.000Z
# 3    2015-02-25T00:00:00.000Z
# 4    2017-07-25T00:00:00.000Z
# ..                        ...
# 100  2020-07-13T00:00:00.000Z
# 101  2022-07-12T08:03:11.000Z
# 102  2021-08-26T13:40:22.000Z
# 103  2014-08-05T00:00:00.000Z
# 104  2020-08-01T00:00:00.000Z
#
#                                                   tags    max_supply  \
# 0    [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1    [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2    [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 3    [stablecoin, asset-backed-stablecoin, ethereum...           NaN
# 4    [marketplace, centralized-exchange, payments, ...           NaN
# ..                                                 ...           ...
# 100  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 101  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 102  [pos, ethereum-ecosystem, layer-1, ftx-bankrup...           NaN
# 103  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 104  [memes, ethereum-ecosystem, doggone-doggerel, ...           NaN
#
#      circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0          1.980887e+07  1.980887e+07            False       NaN         1
# 1          1.204907e+08  1.204907e+08             True       NaN         2
# 2          5.749312e+10  9.998667e+10            False       NaN         3
# 3          1.374514e+11  1.414371e+11             True       NaN         4
# 4          1.440062e+08  1.440062e+08            False       NaN         5
# ..                  ...           ...              ...       ...       ...
# 100        4.107793e+08  4.491156e+08            False       NaN        11
# 101        3.009569e+09  1.000000e+10            False       NaN        12
# 102        2.539973e+09  5.119662e+09             True       NaN        13
# 103        3.039840e+10  5.000179e+10            False       NaN        14
# 104        5.892553e+14  5.895084e+14            False       NaN        15
#
#     self_reported_circulating_supply self_reported_market_cap tvl_ratio  \
# 0                               None                     None      None
# 1                               None                     None      None
# 2                               None                     None      None
# 3                               None                     None      None
# 4                               None                     None      None
# ..                               ...                      ...       ...
# 100                             None                     None      None
# 101                             None                     None      None
# 102                             None                     None      None
# 103                             None                     None      None
# 104                             None                     None      None
#
#                  last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0    2025-01-12T02:24:00.000Z     94457.015041          1.851325e+10
# 1    2025-01-12T02:25:00.000Z      3279.397927          1.143149e+10
# 2    2025-01-12T02:25:00.000Z         2.535086          8.517734e+09
# 3    2025-01-12T02:25:00.000Z         0.999576          5.697144e+10
# 4    2025-01-12T02:25:00.000Z       696.179877          1.292050e+09
# ..                        ...              ...                   ...
# 100  2025-01-12T02:33:00.000Z        37.131054          2.610146e+08
# 101  2025-01-12T02:33:00.000Z         4.912195          9.300553e+08
# 102  2025-01-12T02:33:00.000Z         5.389915          1.444905e+08
# 103  2025-01-12T02:33:00.000Z         0.439861          7.715890e+08
# 104  2025-01-12T02:33:00.000Z         0.000022          4.092938e+08
#
#      quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       -69.0373                     0.151337
# 1                       -55.2971                     0.065381
# 2                        61.9578                     0.938189
# 3                       -50.6764                    -0.007169
# 4                       -21.1115                    -0.006519
# ..                           ...                          ...
# 100                     -47.7643                     0.362239
# 101                     -64.6716                    -0.060921
# 102                     -27.3949                    -0.211471
# 103                      25.1876                     1.583251
# 104                     -12.2574                     0.088321
#
#      quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                        0.223224                    -3.777836
# 1                        1.173036                    -9.952299
# 2                        8.257293                     5.894825
# 3                       -0.036164                    -0.027701
# 4                        0.804641                    -2.123581
# ..                            ...                          ...
# 100                      2.347766                   -11.486240
# 101                     -2.972405                    -5.724100
# 102                      0.314330                    -5.363535
# 103                      7.623942                    -1.777630
# 104                      1.949602                    -9.044994
#
#      quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       -5.050193                      8.101317
# 1                      -15.817222                      1.801352
# 2                        8.393307                    269.496688
# 3                       -0.067539                     -0.145226
# 4                       -1.485822                     13.194153
# ..                            ...                           ...
# 100                    -29.297077                     12.614575
# 101                      4.990539                     63.965496
# 102                    -14.922056                      0.032614
# 103                      4.169007                    237.398206
# 104                    -21.788088                    -12.727434
#
#      quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       50.954117          1.871087e+12
# 1                       33.925846          3.951369e+11
# 2                      378.993879          1.457500e+11
# 3                       -0.002712          1.373930e+11
# 4                       21.893160          1.002542e+11
# ..                            ...                   ...
# 100                     27.419374          1.525267e+10
# 101                    120.564737          1.478359e+10
# 102                      4.301628          1.369024e+10
# 103                    388.766592          1.337107e+10
# 104                     25.665384          1.290706e+10
#
#      quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                           56.4584                        1.983597e+12
# 1                           11.9224                        3.951369e+11
# 2                            4.3979                        2.535086e+11
# 3                            4.1457                        1.413771e+11
# 4                            3.0251                        1.002542e+11
# ..                              ...                                 ...
# 100                          0.4603                        2.657650e+10
# 101                          0.4462                        4.912195e+10
# 102                          0.4132                        2.759455e+10
# 103                          0.4035                        2.199384e+10
# 104                          0.3895                        1.291261e+10
#
#     quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0            None  2025-01-12T02:24:00.000Z          NaN           NaN
# 1            None  2025-01-12T02:25:00.000Z          NaN           NaN
# 2            None  2025-01-12T02:25:00.000Z          NaN           NaN
# 3            None  2025-01-12T02:25:00.000Z       1027.0      Ethereum
# 4            None  2025-01-12T02:25:00.000Z          NaN           NaN
# ..            ...                       ...          ...           ...
# 100          None  2025-01-12T02:33:00.000Z          NaN           NaN
# 101          None  2025-01-12T02:33:00.000Z          NaN           NaN
# 102          None  2025-01-12T02:33:00.000Z          NaN           NaN
# 103          None  2025-01-12T02:33:00.000Z          NaN           NaN
# 104          None  2025-01-12T02:33:00.000Z       1027.0      Ethereum
#
#     platform.symbol platform.slug                      platform.token_address  \
# 0               NaN           NaN                                         NaN
# 1               NaN           NaN                                         NaN
# 2               NaN           NaN                                         NaN
# 3               ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4               NaN           NaN                                         NaN
# ..              ...           ...                                         ...
# 100             NaN           NaN                                         NaN
# 101             NaN           NaN                                         NaN
# 102             NaN           NaN                                         NaN
# 103             NaN           NaN                                         NaN
# 104             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                      timestamp
# 0   2025-01-11 18:25:36.978461
# 1   2025-01-11 18:25:36.978461
# 2   2025-01-11 18:25:36.978461
# 3   2025-01-11 18:25:36.978461
# 4   2025-01-11 18:25:36.978461
# ..                         ...
# 100 2025-01-11 18:33:52.782594
# 101 2025-01-11 18:33:52.782594
# 102 2025-01-11 18:33:52.782594
# 103 2025-01-11 18:33:52.782594
# 104 2025-01-11 18:33:52.782594
#
# [105 rows x 37 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
df
# Out:
#         id         name symbol       slug  num_market_pairs  \
# 0        1      Bitcoin    BTC    bitcoin             11860
# 1     1027     Ethereum    ETH   ethereum              9814
# 2       52          XRP    XRP        xrp              1500
# 3      825  Tether USDt   USDT     tether            112246
# 4     1839          BNB    BNB        bnb              2330
# ..     ...          ...    ...        ...               ...
# 100   5805    Avalanche   AVAX  avalanche               841
# 101  20947          Sui    SUI        sui               516
# 102  11419      Toncoin    TON    toncoin               647
# 103    512      Stellar    XLM    stellar               659
# 104   5994    Shiba Inu   SHIB  shiba-inu               925
#
#                    date_added  \
# 0    2010-07-13T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2013-08-04T00:00:00.000Z
# 3    2015-02-25T00:00:00.000Z
# 4    2017-07-25T00:00:00.000Z
# ..                        ...
# 100  2020-07-13T00:00:00.000Z
# 101  2022-07-12T08:03:11.000Z
# 102  2021-08-26T13:40:22.000Z
# 103  2014-08-05T00:00:00.000Z
# 104  2020-08-01T00:00:00.000Z
#
#                                                   tags         max_supply  \
# 0    [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1    [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2    [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 3    [stablecoin, asset-backed-stablecoin, ethereum...                NaN
# 4    [marketplace, centralized-exchange, payments, ...                NaN
# ..                                                 ...                ...
# 100  [defi, smart-contracts, three-arrows-capital-p...    715748719.00000
# 101  [binance-launchpool, coinbase-ventures-portfol...  10000000000.00000
# 102  [pos, ethereum-ecosystem, layer-1, ftx-bankrup...                NaN
# 103  [medium-of-exchange, enterprise-solutions, dec...  50001806812.00000
# 104  [memes, ethereum-ecosystem, doggone-doggerel, ...                NaN
#
#        circulating_supply          total_supply  infinite_supply  platform  \
# 0          19808871.00000        19808871.00000            False       NaN
# 1         120490689.42870       120490689.42870             True       NaN
# 2       57493120449.00000     99986673391.00000            False       NaN
# 3      137451354879.70145    141437091577.73459             True       NaN
# 4         144006234.72000       144006234.72000            False       NaN
# ..                    ...                   ...              ...       ...
# 100       410779250.42508       449115550.42508            False       NaN
# 101      3009569341.53389     10000000000.00000            False       NaN
# 102      2539973291.08571      5119662241.25866             True       NaN
# 103     30398402756.72007     50001786899.90237            False       NaN
# 104 589255266754629.25000 589508432618995.62500            False       NaN
#
#      cmc_rank self_reported_circulating_supply self_reported_market_cap  \
# 0           1                             None                     None
# 1           2                             None                     None
# 2           3                             None                     None
# 3           4                             None                     None
# 4           5                             None                     None
# ..        ...                              ...                      ...
# 100        11                             None                     None
# 101        12                             None                     None
# 102        13                             None                     None
# 103        14                             None                     None
# 104        15                             None                     None
#
#     tvl_ratio              last_updated  quote.USD.price  \
# 0        None  2025-01-12T02:24:00.000Z      94457.01504
# 1        None  2025-01-12T02:25:00.000Z       3279.39793
# 2        None  2025-01-12T02:25:00.000Z          2.53509
# 3        None  2025-01-12T02:25:00.000Z          0.99958
# 4        None  2025-01-12T02:25:00.000Z        696.17988
# ..        ...                       ...              ...
# 100      None  2025-01-12T02:33:00.000Z         37.13105
# 101      None  2025-01-12T02:33:00.000Z          4.91220
# 102      None  2025-01-12T02:33:00.000Z          5.38992
# 103      None  2025-01-12T02:33:00.000Z          0.43986
# 104      None  2025-01-12T02:33:00.000Z          0.00002
#
#      quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0       18513254358.36298                    -69.03730
# 1       11431491485.65555                    -55.29710
# 2        8517734042.92319                     61.95780
# 3       56971435874.13089                    -50.67640
# 4        1292049930.42098                    -21.11150
# ..                    ...                          ...
# 100       261014609.42255                    -47.76430
# 101       930055292.13534                    -64.67160
# 102       144490465.38199                    -27.39490
# 103       771589006.21979                     25.18760
# 104       409293801.23608                    -12.25740
#
#      quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                        0.15134                       0.22322
# 1                        0.06538                       1.17304
# 2                        0.93819                       8.25729
# 3                       -0.00717                      -0.03616
# 4                       -0.00652                       0.80464
# ..                           ...                           ...
# 100                      0.36224                       2.34777
# 101                     -0.06092                      -2.97241
# 102                     -0.21147                       0.31433
# 103                      1.58325                       7.62394
# 104                      0.08832                       1.94960
#
#      quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                       -3.77784                      -5.05019
# 1                       -9.95230                     -15.81722
# 2                        5.89483                       8.39331
# 3                       -0.02770                      -0.06754
# 4                       -2.12358                      -1.48582
# ..                           ...                           ...
# 100                    -11.48624                     -29.29708
# 101                     -5.72410                       4.99054
# 102                     -5.36353                     -14.92206
# 103                     -1.77763                       4.16901
# 104                     -9.04499                     -21.78809
#
#      quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                         8.10132                      50.95412
# 1                         1.80135                      33.92585
# 2                       269.49669                     378.99388
# 3                        -0.14523                      -0.00271
# 4                        13.19415                      21.89316
# ..                            ...                           ...
# 100                      12.61457                      27.41937
# 101                      63.96550                     120.56474
# 102                       0.03261                       4.30163
# 103                     237.39821                     388.76659
# 104                     -12.72743                      25.66538
#
#      quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0     1871086825999.21558                        56.45840
# 1      395136917081.93982                        11.92240
# 2      145749997173.66370                         4.39790
# 3      137393035464.48070                         4.14570
# 4      100254242775.98715                         3.02510
# ..                    ...                             ...
# 100     15252666389.37323                         0.46030
# 101     14783592054.98581                         0.44620
# 102     13690240965.18519                         0.41320
# 103     13371068671.51570                         0.40350
# 104     12907064962.40658                         0.38950
#
#      quote.USD.fully_diluted_market_cap quote.USD.tvl  \
# 0                   1983597315868.40991          None
# 1                    395136917081.94000          None
# 2                    253508586828.14999          None
# 3                    141377081049.07001          None
# 4                    100254242775.99001          None
# ..                                  ...           ...
# 100                   26576504091.26000          None
# 101                   49121951938.32000          None
# 102                   27594545969.90000          None
# 103                   21993839542.62000          None
# 104                   12912610315.06000          None
#
#        quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0    2025-01-12T02:24:00.000Z          NaN           NaN             NaN
# 1    2025-01-12T02:25:00.000Z          NaN           NaN             NaN
# 2    2025-01-12T02:25:00.000Z          NaN           NaN             NaN
# 3    2025-01-12T02:25:00.000Z   1027.00000      Ethereum             ETH
# 4    2025-01-12T02:25:00.000Z          NaN           NaN             NaN
# ..                        ...          ...           ...             ...
# 100  2025-01-12T02:33:00.000Z          NaN           NaN             NaN
# 101  2025-01-12T02:33:00.000Z          NaN           NaN             NaN
# 102  2025-01-12T02:33:00.000Z          NaN           NaN             NaN
# 103  2025-01-12T02:33:00.000Z          NaN           NaN             NaN
# 104  2025-01-12T02:33:00.000Z   1027.00000      Ethereum             ETH
#
#     platform.slug                      platform.token_address  \
# 0             NaN                                         NaN
# 1             NaN                                         NaN
# 2             NaN                                         NaN
# 3        ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4             NaN                                         NaN
# ..            ...                                         ...
# 100           NaN                                         NaN
# 101           NaN                                         NaN
# 102           NaN                                         NaN
# 103           NaN                                         NaN
# 104      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                      timestamp
# 0   2025-01-11 18:25:36.978461
# 1   2025-01-11 18:25:36.978461
# 2   2025-01-11 18:25:36.978461
# 3   2025-01-11 18:25:36.978461
# 4   2025-01-11 18:25:36.978461
# ..                         ...
# 100 2025-01-11 18:33:52.782594
# 101 2025-01-11 18:33:52.782594
# 102 2025-01-11 18:33:52.782594
# 103 2025-01-11 18:33:52.782594
# 104 2025-01-11 18:33:52.782594
#
# [105 rows x 37 columns]

# %%
df3 = df.groupby('name',sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.17309                       0.25369
# Ethereum                         0.13657                       1.24272
# XRP                              1.05452                       8.41846
# Tether USDt                     -0.01319                      -0.03910
# BNB                              0.00930                       0.76680
# Solana                           0.25227                       0.43093
# Dogecoin                         0.40963                       1.91891
# USDC                            -0.00820                      -0.00610
# Cardano                          0.34025                      10.96085
# TRON                            -0.05015                      -1.14797
# Avalanche                        0.31719                       2.28646
# Sui                             -0.21934                      -3.04757
# Toncoin                         -0.24208                       0.33258
# Stellar                          1.30284                       7.40581
# Shiba Inu                       -0.00600                       1.85657
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -3.74075                      -4.92695
# Ethereum                        -9.88547                     -15.76205
# XRP                              6.12854                       8.56738
# Tether USDt                     -0.05325                      -0.07431
# BNB                             -2.10481                      -1.61923
# Solana                         -13.29288                     -17.41268
# Dogecoin                       -13.45565                     -16.15772
# USDC                            -0.02165                       0.00262
# Cardano                         -3.70847                      -7.89958
# TRON                            -9.73124                     -18.34260
# Avalanche                      -11.73195                     -29.33888
# Sui                             -5.83040                       4.90001
# Toncoin                         -5.42181                     -14.93535
# Stellar                         -2.30472                       3.78376
# Shiba Inu                       -9.22353                     -21.89379
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                           7.96370                      51.04291
# Ethereum                          1.67674                      34.00129
# XRP                             269.37595                     379.62880
# Tether USDt                      -0.16937                      -0.01215
# BNB                              13.12037                      21.94378
# Solana                           -9.27442                      26.03283
# Dogecoin                        -11.41706                     209.37180
# USDC                              0.00525                       0.00737
# Cardano                          85.49577                     197.17285
# TRON                             31.70462                      48.19544
# Avalanche                        12.24108                      27.35724
# Sui                              63.35461                     120.45074
# Toncoin                          -0.34164                       4.29534
# Stellar                         235.90499                     387.21121
# Shiba Inu                       -13.23173                      25.48874

# %%
df4 = df3.stack()
df5 = df4.to_frame(name='values')
pd.set_option('display.max_rows', None)
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.17309
#             quote.USD.percent_change_24h   0.25369
#             quote.USD.percent_change_7d   -3.74075
#             quote.USD.percent_change_30d  -4.92695
#             quote.USD.percent_change_60d   7.96370
#             quote.USD.percent_change_90d  51.04291
# Ethereum    quote.USD.percent_change_1h    0.13657
#             quote.USD.percent_change_24h   1.24272
#             quote.USD.percent_change_7d   -9.88547
#             quote.USD.percent_change_30d -15.76205
#             quote.USD.percent_change_60d   1.67674
#             quote.USD.percent_change_90d  34.00129
# XRP         quote.USD.percent_change_1h    1.05452
#             quote.USD.percent_change_24h   8.41846
#             quote.USD.percent_change_7d    6.12854
#             quote.USD.percent_change_30d   8.56738
#             quote.USD.percent_change_60d 269.37595
#             quote.USD.percent_change_90d 379.62880
# Tether USDt quote.USD.percent_change_1h   -0.01319
#             quote.USD.percent_change_24h  -0.03910
#             quote.USD.percent_change_7d   -0.05325
#             quote.USD.percent_change_30d  -0.07431
#             quote.USD.percent_change_60d  -0.16937
#             quote.USD.percent_change_90d  -0.01215
# BNB         quote.USD.percent_change_1h    0.00930
#             quote.USD.percent_change_24h   0.76680
#             quote.USD.percent_change_7d   -2.10481
#             quote.USD.percent_change_30d  -1.61923
#             quote.USD.percent_change_60d  13.12037
#             quote.USD.percent_change_90d  21.94378
# Solana      quote.USD.percent_change_1h    0.25227
#             quote.USD.percent_change_24h   0.43093
#             quote.USD.percent_change_7d  -13.29288
#             quote.USD.percent_change_30d -17.41268
#             quote.USD.percent_change_60d  -9.27442
#             quote.USD.percent_change_90d  26.03283
# Dogecoin    quote.USD.percent_change_1h    0.40963
#             quote.USD.percent_change_24h   1.91891
#             quote.USD.percent_change_7d  -13.45565
#             quote.USD.percent_change_30d -16.15772
#             quote.USD.percent_change_60d -11.41706
#             quote.USD.percent_change_90d 209.37180
# USDC        quote.USD.percent_change_1h   -0.00820
#             quote.USD.percent_change_24h  -0.00610
#             quote.USD.percent_change_7d   -0.02165
#             quote.USD.percent_change_30d   0.00262
#             quote.USD.percent_change_60d   0.00525
#             quote.USD.percent_change_90d   0.00737
# Cardano     quote.USD.percent_change_1h    0.34025
#             quote.USD.percent_change_24h  10.96085
#             quote.USD.percent_change_7d   -3.70847
#             quote.USD.percent_change_30d  -7.89958
#             quote.USD.percent_change_60d  85.49577
#             quote.USD.percent_change_90d 197.17285
# TRON        quote.USD.percent_change_1h   -0.05015
#             quote.USD.percent_change_24h  -1.14797
#             quote.USD.percent_change_7d   -9.73124
#             quote.USD.percent_change_30d -18.34260
#             quote.USD.percent_change_60d  31.70462
#             quote.USD.percent_change_90d  48.19544
# Avalanche   quote.USD.percent_change_1h    0.31719
#             quote.USD.percent_change_24h   2.28646
#             quote.USD.percent_change_7d  -11.73195
#             quote.USD.percent_change_30d -29.33888
#             quote.USD.percent_change_60d  12.24108
#             quote.USD.percent_change_90d  27.35724
# Sui         quote.USD.percent_change_1h   -0.21934
#             quote.USD.percent_change_24h  -3.04757
#             quote.USD.percent_change_7d   -5.83040
#             quote.USD.percent_change_30d   4.90001
#             quote.USD.percent_change_60d  63.35461
#             quote.USD.percent_change_90d 120.45074
# Toncoin     quote.USD.percent_change_1h   -0.24208
#             quote.USD.percent_change_24h   0.33258
#             quote.USD.percent_change_7d   -5.42181
#             quote.USD.percent_change_30d -14.93535
#             quote.USD.percent_change_60d  -0.34164
#             quote.USD.percent_change_90d   4.29534
# Stellar     quote.USD.percent_change_1h    1.30284
#             quote.USD.percent_change_24h   7.40581
#             quote.USD.percent_change_7d   -2.30472
#             quote.USD.percent_change_30d   3.78376
#             quote.USD.percent_change_60d 235.90499
#             quote.USD.percent_change_90d 387.21121
# Shiba Inu   quote.USD.percent_change_1h   -0.00600
#             quote.USD.percent_change_24h   1.85657
#             quote.USD.percent_change_7d   -9.22353
#             quote.USD.percent_change_30d -21.89379
#             quote.USD.percent_change_60d -13.23173
#             quote.USD.percent_change_90d  25.48874

# %%
df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.17309
# 1       Bitcoin  quote.USD.percent_change_24h   0.25369
# 2       Bitcoin   quote.USD.percent_change_7d  -3.74075
# 3       Bitcoin  quote.USD.percent_change_30d  -4.92695
# 4       Bitcoin  quote.USD.percent_change_60d   7.96370
# 5       Bitcoin  quote.USD.percent_change_90d  51.04291
# 6      Ethereum   quote.USD.percent_change_1h   0.13657
# 7      Ethereum  quote.USD.percent_change_24h   1.24272
# 8      Ethereum   quote.USD.percent_change_7d  -9.88547
# 9      Ethereum  quote.USD.percent_change_30d -15.76205
# 10     Ethereum  quote.USD.percent_change_60d   1.67674
# 11     Ethereum  quote.USD.percent_change_90d  34.00129
# 12          XRP   quote.USD.percent_change_1h   1.05452
# 13          XRP  quote.USD.percent_change_24h   8.41846
# 14          XRP   quote.USD.percent_change_7d   6.12854
# 15          XRP  quote.USD.percent_change_30d   8.56738
# 16          XRP  quote.USD.percent_change_60d 269.37595
# 17          XRP  quote.USD.percent_change_90d 379.62880
# 18  Tether USDt   quote.USD.percent_change_1h  -0.01319
# 19  Tether USDt  quote.USD.percent_change_24h  -0.03910
# 20  Tether USDt   quote.USD.percent_change_7d  -0.05325
# 21  Tether USDt  quote.USD.percent_change_30d  -0.07431
# 22  Tether USDt  quote.USD.percent_change_60d  -0.16937
# 23  Tether USDt  quote.USD.percent_change_90d  -0.01215
# 24          BNB   quote.USD.percent_change_1h   0.00930
# 25          BNB  quote.USD.percent_change_24h   0.76680
# 26          BNB   quote.USD.percent_change_7d  -2.10481
# 27          BNB  quote.USD.percent_change_30d  -1.61923
# 28          BNB  quote.USD.percent_change_60d  13.12037
# 29          BNB  quote.USD.percent_change_90d  21.94378
# 30       Solana   quote.USD.percent_change_1h   0.25227
# 31       Solana  quote.USD.percent_change_24h   0.43093
# 32       Solana   quote.USD.percent_change_7d -13.29288
# 33       Solana  quote.USD.percent_change_30d -17.41268
# 34       Solana  quote.USD.percent_change_60d  -9.27442
# 35       Solana  quote.USD.percent_change_90d  26.03283
# 36     Dogecoin   quote.USD.percent_change_1h   0.40963
# 37     Dogecoin  quote.USD.percent_change_24h   1.91891
# 38     Dogecoin   quote.USD.percent_change_7d -13.45565
# 39     Dogecoin  quote.USD.percent_change_30d -16.15772
# 40     Dogecoin  quote.USD.percent_change_60d -11.41706
# 41     Dogecoin  quote.USD.percent_change_90d 209.37180
# 42         USDC   quote.USD.percent_change_1h  -0.00820
# 43         USDC  quote.USD.percent_change_24h  -0.00610
# 44         USDC   quote.USD.percent_change_7d  -0.02165
# 45         USDC  quote.USD.percent_change_30d   0.00262
# 46         USDC  quote.USD.percent_change_60d   0.00525
# 47         USDC  quote.USD.percent_change_90d   0.00737
# 48      Cardano   quote.USD.percent_change_1h   0.34025
# 49      Cardano  quote.USD.percent_change_24h  10.96085
# 50      Cardano   quote.USD.percent_change_7d  -3.70847
# 51      Cardano  quote.USD.percent_change_30d  -7.89958
# 52      Cardano  quote.USD.percent_change_60d  85.49577
# 53      Cardano  quote.USD.percent_change_90d 197.17285
# 54         TRON   quote.USD.percent_change_1h  -0.05015
# 55         TRON  quote.USD.percent_change_24h  -1.14797
# 56         TRON   quote.USD.percent_change_7d  -9.73124
# 57         TRON  quote.USD.percent_change_30d -18.34260
# 58         TRON  quote.USD.percent_change_60d  31.70462
# 59         TRON  quote.USD.percent_change_90d  48.19544
# 60    Avalanche   quote.USD.percent_change_1h   0.31719
# 61    Avalanche  quote.USD.percent_change_24h   2.28646
# 62    Avalanche   quote.USD.percent_change_7d -11.73195
# 63    Avalanche  quote.USD.percent_change_30d -29.33888
# 64    Avalanche  quote.USD.percent_change_60d  12.24108
# 65    Avalanche  quote.USD.percent_change_90d  27.35724
# 66          Sui   quote.USD.percent_change_1h  -0.21934
# 67          Sui  quote.USD.percent_change_24h  -3.04757
# 68          Sui   quote.USD.percent_change_7d  -5.83040
# 69          Sui  quote.USD.percent_change_30d   4.90001
# 70          Sui  quote.USD.percent_change_60d  63.35461
# 71          Sui  quote.USD.percent_change_90d 120.45074
# 72      Toncoin   quote.USD.percent_change_1h  -0.24208
# 73      Toncoin  quote.USD.percent_change_24h   0.33258
# 74      Toncoin   quote.USD.percent_change_7d  -5.42181
# 75      Toncoin  quote.USD.percent_change_30d -14.93535
# 76      Toncoin  quote.USD.percent_change_60d  -0.34164
# 77      Toncoin  quote.USD.percent_change_90d   4.29534
# 78      Stellar   quote.USD.percent_change_1h   1.30284
# 79      Stellar  quote.USD.percent_change_24h   7.40581
# 80      Stellar   quote.USD.percent_change_7d  -2.30472
# 81      Stellar  quote.USD.percent_change_30d   3.78376
# 82      Stellar  quote.USD.percent_change_60d 235.90499
# 83      Stellar  quote.USD.percent_change_90d 387.21121
# 84    Shiba Inu   quote.USD.percent_change_1h  -0.00600
# 85    Shiba Inu  quote.USD.percent_change_24h   1.85657
# 86    Shiba Inu   quote.USD.percent_change_7d  -9.22353
# 87    Shiba Inu  quote.USD.percent_change_30d -21.89379
# 88    Shiba Inu  quote.USD.percent_change_60d -13.23173
# 89    Shiba Inu  quote.USD.percent_change_90d  25.48874

# %%
df7 = df6.rename(columns={'level_1':'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.17309
# 1       Bitcoin  quote.USD.percent_change_24h   0.25369
# 2       Bitcoin   quote.USD.percent_change_7d  -3.74075
# 3       Bitcoin  quote.USD.percent_change_30d  -4.92695
# 4       Bitcoin  quote.USD.percent_change_60d   7.96370
# 5       Bitcoin  quote.USD.percent_change_90d  51.04291
# 6      Ethereum   quote.USD.percent_change_1h   0.13657
# 7      Ethereum  quote.USD.percent_change_24h   1.24272
# 8      Ethereum   quote.USD.percent_change_7d  -9.88547
# 9      Ethereum  quote.USD.percent_change_30d -15.76205
# 10     Ethereum  quote.USD.percent_change_60d   1.67674
# 11     Ethereum  quote.USD.percent_change_90d  34.00129
# 12          XRP   quote.USD.percent_change_1h   1.05452
# 13          XRP  quote.USD.percent_change_24h   8.41846
# 14          XRP   quote.USD.percent_change_7d   6.12854
# 15          XRP  quote.USD.percent_change_30d   8.56738
# 16          XRP  quote.USD.percent_change_60d 269.37595
# 17          XRP  quote.USD.percent_change_90d 379.62880
# 18  Tether USDt   quote.USD.percent_change_1h  -0.01319
# 19  Tether USDt  quote.USD.percent_change_24h  -0.03910
# 20  Tether USDt   quote.USD.percent_change_7d  -0.05325
# 21  Tether USDt  quote.USD.percent_change_30d  -0.07431
# 22  Tether USDt  quote.USD.percent_change_60d  -0.16937
# 23  Tether USDt  quote.USD.percent_change_90d  -0.01215
# 24          BNB   quote.USD.percent_change_1h   0.00930
# 25          BNB  quote.USD.percent_change_24h   0.76680
# 26          BNB   quote.USD.percent_change_7d  -2.10481
# 27          BNB  quote.USD.percent_change_30d  -1.61923
# 28          BNB  quote.USD.percent_change_60d  13.12037
# 29          BNB  quote.USD.percent_change_90d  21.94378
# 30       Solana   quote.USD.percent_change_1h   0.25227
# 31       Solana  quote.USD.percent_change_24h   0.43093
# 32       Solana   quote.USD.percent_change_7d -13.29288
# 33       Solana  quote.USD.percent_change_30d -17.41268
# 34       Solana  quote.USD.percent_change_60d  -9.27442
# 35       Solana  quote.USD.percent_change_90d  26.03283
# 36     Dogecoin   quote.USD.percent_change_1h   0.40963
# 37     Dogecoin  quote.USD.percent_change_24h   1.91891
# 38     Dogecoin   quote.USD.percent_change_7d -13.45565
# 39     Dogecoin  quote.USD.percent_change_30d -16.15772
# 40     Dogecoin  quote.USD.percent_change_60d -11.41706
# 41     Dogecoin  quote.USD.percent_change_90d 209.37180
# 42         USDC   quote.USD.percent_change_1h  -0.00820
# 43         USDC  quote.USD.percent_change_24h  -0.00610
# 44         USDC   quote.USD.percent_change_7d  -0.02165
# 45         USDC  quote.USD.percent_change_30d   0.00262
# 46         USDC  quote.USD.percent_change_60d   0.00525
# 47         USDC  quote.USD.percent_change_90d   0.00737
# 48      Cardano   quote.USD.percent_change_1h   0.34025
# 49      Cardano  quote.USD.percent_change_24h  10.96085
# 50      Cardano   quote.USD.percent_change_7d  -3.70847
# 51      Cardano  quote.USD.percent_change_30d  -7.89958
# 52      Cardano  quote.USD.percent_change_60d  85.49577
# 53      Cardano  quote.USD.percent_change_90d 197.17285
# 54         TRON   quote.USD.percent_change_1h  -0.05015
# 55         TRON  quote.USD.percent_change_24h  -1.14797
# 56         TRON   quote.USD.percent_change_7d  -9.73124
# 57         TRON  quote.USD.percent_change_30d -18.34260
# 58         TRON  quote.USD.percent_change_60d  31.70462
# 59         TRON  quote.USD.percent_change_90d  48.19544
# 60    Avalanche   quote.USD.percent_change_1h   0.31719
# 61    Avalanche  quote.USD.percent_change_24h   2.28646
# 62    Avalanche   quote.USD.percent_change_7d -11.73195
# 63    Avalanche  quote.USD.percent_change_30d -29.33888
# 64    Avalanche  quote.USD.percent_change_60d  12.24108
# 65    Avalanche  quote.USD.percent_change_90d  27.35724
# 66          Sui   quote.USD.percent_change_1h  -0.21934
# 67          Sui  quote.USD.percent_change_24h  -3.04757
# 68          Sui   quote.USD.percent_change_7d  -5.83040
# 69          Sui  quote.USD.percent_change_30d   4.90001
# 70          Sui  quote.USD.percent_change_60d  63.35461
# 71          Sui  quote.USD.percent_change_90d 120.45074
# 72      Toncoin   quote.USD.percent_change_1h  -0.24208
# 73      Toncoin  quote.USD.percent_change_24h   0.33258
# 74      Toncoin   quote.USD.percent_change_7d  -5.42181
# 75      Toncoin  quote.USD.percent_change_30d -14.93535
# 76      Toncoin  quote.USD.percent_change_60d  -0.34164
# 77      Toncoin  quote.USD.percent_change_90d   4.29534
# 78      Stellar   quote.USD.percent_change_1h   1.30284
# 79      Stellar  quote.USD.percent_change_24h   7.40581
# 80      Stellar   quote.USD.percent_change_7d  -2.30472
# 81      Stellar  quote.USD.percent_change_30d   3.78376
# 82      Stellar  quote.USD.percent_change_60d 235.90499
# 83      Stellar  quote.USD.percent_change_90d 387.21121
# 84    Shiba Inu   quote.USD.percent_change_1h  -0.00600
# 85    Shiba Inu  quote.USD.percent_change_24h   1.85657
# 86    Shiba Inu   quote.USD.percent_change_7d  -9.22353
# 87    Shiba Inu  quote.USD.percent_change_30d -21.89379
# 88    Shiba Inu  quote.USD.percent_change_60d -13.23173
# 89    Shiba Inu  quote.USD.percent_change_90d  25.48874

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h'], ['1h'])
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h'], ['24h'])
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_7d'], ['7d'])
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_30d'], ['30d'])
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_60d'], ['60d'])
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_90d'], ['90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.17309
# 1       Bitcoin            24h   0.25369
# 2       Bitcoin             7d  -3.74075
# 3       Bitcoin            30d  -4.92695
# 4       Bitcoin            60d   7.96370
# 5       Bitcoin            90d  51.04291
# 6      Ethereum             1h   0.13657
# 7      Ethereum            24h   1.24272
# 8      Ethereum             7d  -9.88547
# 9      Ethereum            30d -15.76205
# 10     Ethereum            60d   1.67674
# 11     Ethereum            90d  34.00129
# 12          XRP             1h   1.05452
# 13          XRP            24h   8.41846
# 14          XRP             7d   6.12854
# 15          XRP            30d   8.56738
# 16          XRP            60d 269.37595
# 17          XRP            90d 379.62880
# 18  Tether USDt             1h  -0.01319
# 19  Tether USDt            24h  -0.03910
# 20  Tether USDt             7d  -0.05325
# 21  Tether USDt            30d  -0.07431
# 22  Tether USDt            60d  -0.16937
# 23  Tether USDt            90d  -0.01215
# 24          BNB             1h   0.00930
# 25          BNB            24h   0.76680
# 26          BNB             7d  -2.10481
# 27          BNB            30d  -1.61923
# 28          BNB            60d  13.12037
# 29          BNB            90d  21.94378
# 30       Solana             1h   0.25227
# 31       Solana            24h   0.43093
# 32       Solana             7d -13.29288
# 33       Solana            30d -17.41268
# 34       Solana            60d  -9.27442
# 35       Solana            90d  26.03283
# 36     Dogecoin             1h   0.40963
# 37     Dogecoin            24h   1.91891
# 38     Dogecoin             7d -13.45565
# 39     Dogecoin            30d -16.15772
# 40     Dogecoin            60d -11.41706
# 41     Dogecoin            90d 209.37180
# 42         USDC             1h  -0.00820
# 43         USDC            24h  -0.00610
# 44         USDC             7d  -0.02165
# 45         USDC            30d   0.00262
# 46         USDC            60d   0.00525
# 47         USDC            90d   0.00737
# 48      Cardano             1h   0.34025
# 49      Cardano            24h  10.96085
# 50      Cardano             7d  -3.70847
# 51      Cardano            30d  -7.89958
# 52      Cardano            60d  85.49577
# 53      Cardano            90d 197.17285
# 54         TRON             1h  -0.05015
# 55         TRON            24h  -1.14797
# 56         TRON             7d  -9.73124
# 57         TRON            30d -18.34260
# 58         TRON            60d  31.70462
# 59         TRON            90d  48.19544
# 60    Avalanche             1h   0.31719
# 61    Avalanche            24h   2.28646
# 62    Avalanche             7d -11.73195
# 63    Avalanche            30d -29.33888
# 64    Avalanche            60d  12.24108
# 65    Avalanche            90d  27.35724
# 66          Sui             1h  -0.21934
# 67          Sui            24h  -3.04757
# 68          Sui             7d  -5.83040
# 69          Sui            30d   4.90001
# 70          Sui            60d  63.35461
# 71          Sui            90d 120.45074
# 72      Toncoin             1h  -0.24208
# 73      Toncoin            24h   0.33258
# 74      Toncoin             7d  -5.42181
# 75      Toncoin            30d -14.93535
# 76      Toncoin            60d  -0.34164
# 77      Toncoin            90d   4.29534
# 78      Stellar             1h   1.30284
# 79      Stellar            24h   7.40581
# 80      Stellar             7d  -2.30472
# 81      Stellar            30d   3.78376
# 82      Stellar            60d 235.90499
# 83      Stellar            90d 387.21121
# 84    Shiba Inu             1h  -0.00600
# 85    Shiba Inu            24h   1.85657
# 86    Shiba Inu             7d  -9.22353
# 87    Shiba Inu            30d -21.89379
# 88    Shiba Inu            60d -13.23173
# 89    Shiba Inu            90d  25.48874

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
df9 = df[['name','quote.USD.price','timestamp']]
df10 = df9.query("name == 'Bitcoin'")
df10
# Out:
#        name  quote.USD.price                  timestamp
# 0   Bitcoin      94457.01504 2025-01-11 18:25:36.978461
# 15  Bitcoin      94462.69315 2025-01-11 18:28:51.121290
# 30  Bitcoin      94485.30354 2025-01-11 18:29:51.439172
# 45  Bitcoin      94479.57654 2025-01-11 18:30:51.805275
# 60  Bitcoin      94483.09906 2025-01-11 18:31:52.107772
# 75  Bitcoin      94483.09906 2025-01-11 18:32:52.361597
# 90  Bitcoin      94507.51156 2025-01-11 18:33:52.782594

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
